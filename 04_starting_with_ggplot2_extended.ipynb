# %% [markdown]
# Load the `TidyVerse` package.

# %%
library('tidyverse')
# Out:
# Warning message:
# “Failed to locate timezone database”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# put the libray function call in this cell...
library('tidyverse')

# %% [markdown]
# Let's make a line chart 📈.

# %% [markdown]
# We'll use the `economics` data set. Use the `head` function to preview the data below ↓.

# %%
economics|>head()
# Out:
#   date       pce   pop    psavert uempmed unemploy
# 1 1967-07-01 506.7 198712 12.6    4.5     2944
# 2 1967-08-01 509.8 198911 12.6    4.7     2945
# 3 1967-09-01 515.6 199113 11.9    4.6     2958
# 4 1967-10-01 512.2 199311 12.9    4.9     3143
# 5 1967-11-01 517.4 199498 12.8    4.7     3066
# 6 1967-12-01 525.1 199657 11.8    4.8     3018

# %% [markdown]
# Line charts make use of the line `geom` function. Can you guess the name of this function?
#
# Put your cursor after `geom_` in the cell below and press the `Tab`key . What happens?

# %%
geom_

# %%
# a panel comes up that gives different options for geom_

# %% [markdown]
# Now that you've seen all the available geoms, use the line `geom` to make a line chart from the `economics` data set with **`unemploy` on the  y-axis** and **`date` on the x-axis.**

# %%
# chart code goes here...

encodings = aes(x = date, y = unemploy)  # fill in the correct values for the encodings here
p = ggplot(economics,encodings) + geom_line(color='pink') # fill in the correct arguments here
p

#Alternate way to code this line chart would be to swap out what encoding = and put that directly into the p = line
# Out:
# plot without title

# %%
mpg|>head()
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
encodings = aes(x=count, y=class)

# %%
p = ggplot(mpg,encodings) + geom_bar # fill in the correct arguments here
p
# Out:
# Error in `ggplot_add()`:
# ! Can't add `geom_bar` to a <ggplot> object
# ℹ Did you forget to add parentheses, as in `geom_bar()`?
# Traceback:
#
# 1. `+.gg`(ggplot(mpg, encodings), geom_bar)
# 2. add_ggplot(e1, e2, e2name)
# 3. ggplot_add(object, p, objectname)
# 4. ggplot_add.function(object, p, objectname)
# 5. cli::cli_abort(c("Can't add {.var {object_name}} to a {.cls ggplot} object",
#  .     i = "Did you forget to add parentheses, as in {.fn {object_name}}?"))
# 6. rlang::abort(message, ..., call = call, use_cli_format = TRUE,
#  .     .frame = .frame)
# 7. signal_abort(cnd, .file)
